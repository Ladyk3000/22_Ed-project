# %%
import pandas as pd

# %%
Customers = pd.read_csv('CCCustomers.csv')
Customers = Customers.sort_values('Customer_Since')
# Out:
#       Unnamed: 0  Customer_ID  Gender First name   Last name Date_of_birth  \
# 2740        2740         2158  Female      Rimas       Ammar    1997-01-12
# 4229        4229         4722  Female      Ireen     Maalouf    1981-05-26
# 19            19         1567    Male     Sajjad    AlHamdan    1966-01-05
# 9794        9794         6178  Female    Mahmuna   Benaldjia    1989-12-08
# 6502        6502         5192  Female  Boutheina  Al-Zahrani    1996-07-09
# ...          ...          ...     ...        ...         ...           ...
# 1091        1091          792    Male   Ziauddin  As-Suwaidi    1959-11-08
# 63            63         4057  Female     Sandra       Jaber    1994-06-05
# 7785        7785         4468  Female    Mahmuna     Gaddafi    1997-03-18
# 3309        3309         5948    Male     Sajjad     Qureshi    1990-06-25
# 4543        4543         9099  Female       Afaf      Shihuh    1998-01-25
#
# ...

# %%
Customers_main = Customers[:9655]
Customers_main.to_csv('Customers.csv', index=False)
Customers_main.tail()
# Out:
#       Unnamed: 0  Customer_ID  Gender First name   Last name Date_of_birth  \
# 8693        8693         4646  Female      Rania      Khayat    1983-06-11
# 1091        1091          792    Male   Ziauddin  As-Suwaidi    1959-11-08
# 63            63         4057  Female     Sandra       Jaber    1994-06-05
# 7785        7785         4468  Female    Mahmuna     Gaddafi    1997-03-18
# 3309        3309         5948    Male     Sajjad     Qureshi    1990-06-25
#
#      Agree_for_promo autoplay_card                     Customer_Email  \
# 8693              No            No          RaniaKhayat67@123arab.com
# 1091             Yes           Yes  ZiauddinAs-Suwaidi5@aramco.com.sa
# 63               Yes            No        SandraJaber10@naseej.com.sa
# 7785             Yes           Yes     MahmunaGaddafi68@aramco.com.sa
# 3309              No            No        SajjadQureshi11@123arab.com
#
#                MSISDN    Status  Category Customer_Since  Region Language  \
# ...

# %%
Customers_last = Customers[9655:]
Customers_last.to_csv('Customers_last.csv', index=False)
Customers_last
# Out:
#       Unnamed: 0  Customer_ID  Gender First name Last name Date_of_birth  \
# 4543        4543         9099  Female       Afaf    Shihuh    1998-01-25
# 6619        6619         3924    Male   AbdulHaq      Reza    1996-07-14
# 2839        2839           39    Male      Anjem     Taieb    1981-07-13
# 6579        6579         7781  Female      Katya     Latif    1965-09-27
# 7524        7524         2688    Male      Anwar   Maatouk    1974-01-17
# ...          ...          ...     ...        ...       ...           ...
# 6526        6526         5062  Female      Julia  Trabelsi    1983-01-04
# 3951        3951         4442    Male     Haydar     Abiha    1972-02-16
# 2836        2836         6609  Female     Atikah     Batma    1973-02-13
# 2568        2568         4258  Female       Mona   Nabhani    1993-08-05
# 7875        7875         2445    Male  Saifullah     Nazif    2004-01-08
#
#      Agree_for_promo autoplay_card                   Customer_Email  \
# ...

# %%
All_information = pd.read_csv('AAAll_information.csv')#.drop('Unnamed: 0', axis =1 )
All_information.head()
# Out:
#    Unnamed: 0        date  sms_events  calls_events  data_events  \
# 0           0  2020-01-01    93.40020     166.54317    819.98262
# 1           1  2020-01-02    61.90280     128.52700    609.54177
# 2           2  2020-01-03    26.63946      53.44308    253.16442
# 3           3  2020-01-04    58.74116     117.83914    566.75936
# 4           4  2020-01-05    13.51314      27.16119    128.09592
#
#    mean_call_duration  mean_data_volume  mean_sms_cost  mean_call_cost  \
# 0             3.00548          73.89163       0.296020         0.23838
# 1             2.95532          69.44602       0.279973         0.20090
# 2             3.09473          72.13188       0.266676         0.24692
# 3             3.02477          73.02448       0.295659         0.20518
# 4             3.01652          73.46773       0.269902         0.21685
#
#    mean_data_cost  ...  total_data_cost  total_cost  sms_ARPU  calls_ARPU  \
# ...

# %%
All_information_main = All_information[:839]
All_information_main.to_csv('all_information.csv', index=False)
All_information_main
# Out:
#      Unnamed: 0        date   sms_events  calls_events   data_events  \
# 0             0  2020-01-01     93.40020     166.54317     819.98262
# 1             1  2020-01-02     61.90280     128.52700     609.54177
# 2             2  2020-01-03     26.63946      53.44308     253.16442
# 3             3  2020-01-04     58.74116     117.83914     566.75936
# 4             4  2020-01-05     13.51314      27.16119     128.09592
# ..          ...         ...          ...           ...           ...
# 834         834  2022-04-15  22489.66177   42260.56684  164017.54020
# 835         835  2022-04-16  22100.19105   42032.00850  174462.14430
# 836         836  2022-04-17  22869.09886   42800.43894  167690.88246
# 837         837  2022-04-18  22741.87971   42291.12899  166043.14562
# 838         838  2022-04-19  23248.42170   42833.08295  181387.29350
#
#      mean_call_duration  mean_data_volume  mean_sms_cost  mean_call_cost  \
# ...

# %%
All_information_last = All_information[839:]
All_information_last.to_csv('all_information_last.csv', index=False)
All_information_last
# Out:
#      Unnamed: 0        date   sms_events  calls_events   data_events  \
# 839         839  2022-04-20  23519.12960   41768.35840  175209.91680
# 840         840  2022-04-21  23809.74552   42991.28640  162329.40144
# 841         841  2022-04-22  24085.27440   43171.87140  172710.93240
# 842         842  2022-04-23  23180.51887   41962.89473  145123.17748
# 843         843  2022-04-24  22830.94275   43244.37315  165893.64495
# 844         844  2022-04-25  23194.70404   43512.20166  149311.01422
# 845         845  2022-04-26  25375.90405   43485.16015  150110.19005
# 846         846  2022-04-27  24778.83446   43851.06972  172360.92699
# 847         847  2022-04-28  25595.79403   43731.82349  186081.65180
# 848         848  2022-04-29  25144.51221   43387.87644  165643.50429
# 849         849  2022-04-30  23498.15739   44110.84302  157103.34039
# 850         850  2022-05-01  23626.72192   43232.62014  156906.57558
# 851         851  2022-05-02  23631.27250   44781.12250  158539.10750
# ...
